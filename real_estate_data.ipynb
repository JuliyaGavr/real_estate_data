# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Стиль-заголовков" data-toc-modified-id="Стиль-заголовков-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Стиль заголовков</a></span></li><li><span><a href="#Заполнение-пропусков-и-поиск-аномалий¶" data-toc-modified-id="Заполнение-пропусков-и-поиск-аномалий¶-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Заполнение пропусков и поиск аномалий¶</a></span></li><li><span><a href="#Удаление-дубликатов." data-toc-modified-id="Удаление-дубликатов.-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Удаление дубликатов.</a></span></li><li><span><a href="#Выводы." data-toc-modified-id="Выводы.-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Выводы.</a></span></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span><ul class="toc-item"><li><span><a href="#Выводы" data-toc-modified-id="Выводы-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Дополнительное-исследование:-площадь-(относительная),-цена,-число-комнат,-высота-потолков" data-toc-modified-id="Дополнительное-исследование:-площадь-(относительная),-цена,-число-комнат,-высота-потолков-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Дополнительное исследование: площадь (относительная), цена, число комнат, высота потолков</a></span></li><li><span><a href="#Исследование-времени-продажи-квартир" data-toc-modified-id="Исследование-времени-продажи-квартир-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Исследование времени продажи квартир</a></span></li><li><span><a href="#Зависимость-цены-от-площади,-удаленности-от-центра,-числа-комнат,-этажа,-удалённости-от-центра-и-даты-размещения." data-toc-modified-id="Зависимость-цены-от-площади,-удаленности-от-центра,-числа-комнат,-этажа,-удалённости-от-центра-и-даты-размещения.-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Зависимость цены от площади, удаленности от центра, числа комнат, этажа, удалённости от центра и даты размещения.</a></span></li><li><span><a href="#Исследование-цен-в-населенных-пунктах" data-toc-modified-id="Исследование-цен-в-населенных-пунктах-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Исследование цен в населенных пунктах</a></span></li><li><span><a href="#Исследование-расстояния-до-центра" data-toc-modified-id="Исследование-расстояния-до-центра-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Исследование расстояния до центра</a></span></li><li><span><a href="#Иследование-влияния-основнях-параметров-на-цену-квартир-в-центральном-районе" data-toc-modified-id="Иследование-влияния-основнях-параметров-на-цену-квартир-в-центральном-районе-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Иследование влияния основнях параметров на цену квартир в центральном районе</a></span></li><li><span><a href="#Проверка-по-всему-датасету" data-toc-modified-id="Проверка-по-всему-датасету-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Проверка по всему датасету</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекc Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# ## Изучение данных из файла

# %% [markdown]
# Импорт необходимых инструментов.

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sb

# %% [markdown]
# ### Вывод

# %% [markdown]
# Датасет представлен в формате CSV, чтобы открыть таблицу подойдет функция read_csv().
#
# Прочитаю файл real_estate_data.csv из папки /datasets, атрибут sep метода read_csv() при этом будет равен '\t'. Сохраню его в переменной df.
#
# Просмотрю первые 10 строк таблица и общую информацию о ней, чтобы ознакомиться с данными

# %%
try:
    df = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')
except:
    df = pd.read_csv('real_estate_data.csv', sep='\t')
display(df.head(10))
df.info()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1             7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2            10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3             0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4             2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5            10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6             6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7             5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8            20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9            18   5400000.0       61.00  2017-02-26T00:00:00      3
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0        51.00      8          NaN  ...
# 1             NaN          11.0        18.60      1          NaN  ...
# ...

# %% [markdown]
# В таблице 21 столбец. В соответствии с имеющейся документацией к данным:
# - airports_nearest — расстояние до ближайшего аэропорта в метрах (м)
# - balcony — число балконов
# - ceiling_height — высота потолков (м)
# - cityCenters_nearest — расстояние до центра города (м)
# - days_exposition — сколько дней было размещено объявление (от публикации до снятия)
# - first_day_exposition — дата публикации
# - floor — этаж
# - floors_total — всего этажей в доме
# - is_apartment — апартаменты (булев тип)
# - kitchen_area — площадь кухни в квадратных метрах (м²)
# - last_price — цена на момент снятия с публикации
# - living_area — жилая площадь в квадратных метрах (м²)
# - locality_name — название населённого пункта
# - open_plan — свободная планировка (булев тип)
# - parks_around3000 — число парков в радиусе 3 км
# - parks_nearest — расстояние до ближайшего парка (м)
# - ponds_around3000 — число водоёмов в радиусе 3 км
# - ponds_nearest — расстояние до ближайшего водоёма (м)
# - rooms — число комнат
# - studio — квартира-студия (булев тип)
# - total_area — площадь квартиры в квадратных метрах (м²)
# - total_images — число фотографий квартиры в объявлении
#
# Присутствуют разные типы данных - bool, float, int и object.
#
# **Выводы**
#
# - Название сityCenters_nearest (расстояние до центра города) написано в соответствии с документацией, но не в "змеином_регистре" - это нарушение хорошего стиля, заменю его на сity_сenters_nearest;
# - Пропуски в столбцах: ceiling_height, living_area, is_apartment, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition;
# - Тип переменной is_apartment не соотвествует документации, должен быть bool;
# - Для экономии памяти и удобства расчета last_price целесообразно перевести в тип int;
# - Столбцы floors_total, balcony, parks_around3000, ponds_around3000, days_exposition по смыслу не могут содержать дробные числа, необходимо перевести в int;
# - В столбце first_day_exposition необходимо преобразовать к формату datetime, так с ним будет удобнее работать.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Стиль заголовков
# Выведу на экран названия столбцов:

# %%
df.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'cityCenters_nearest',
#        'parks_around3000', 'parks_nearest', 'ponds_around3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %% [markdown]
# Приведу название 'cityCenters_nearest' в соответствие с хорошим стилем.
# Для этого переименуйте колонку 'city_сenters_nearest' используя функццию rename().
# Выведу на экран названия столбцов для проверки рузультата.

# %%
df = df.rename(columns={'cityCenters_nearest': 'city_сenters_neares'}) 
df.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'city_сenters_neares',
#        'parks_around3000', 'parks_nearest', 'ponds_around3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %% [markdown]
# Замена прошла успешно.

# %% [markdown]
# ### Заполнение пропусков и поиск аномалий¶

# %% [markdown]
# На предыдущем этапе обнаружено несколько колонок, в которых могут быть пропуски. Проверю это, применив функции isna() и sum() и mean(), солью все в одну таблицу для наглядности. В столбце с названием 0 - количество нулевых значений, 1 - доля нулевых значений.

# %%
display(pd.concat([df.isna().sum(), df.isna().mean()], axis=1))
# Out:
#                           0         1
# total_images              0  0.000000
# last_price                0  0.000000
# total_area                0  0.000000
# first_day_exposition      0  0.000000
# rooms                     0  0.000000
# ceiling_height         9195  0.387991
# floors_total             86  0.003629
# living_area            1903  0.080299
# floor                     0  0.000000
# is_apartment          20924  0.882906
# studio                    0  0.000000
# open_plan                 0  0.000000
# kitchen_area           2278  0.096122
# balcony               11519  0.486054
# locality_name            49  0.002068
# airports_nearest       5542  0.233850
# city_сenters_neares    5519  0.232879
# parks_around3000       5518  0.232837
# parks_nearest         15620  0.659100
# ponds_around3000       5518  0.232837
# ponds_nearest         14589  0.615596
# days_exposition        3181  0.134225

# %% [markdown]
# Первый столбец с пропусками ceiling_height (высота потолков) - 40% пропусков.
# Выведу его уникальные значения и их количество функцией value_counts().
# Построю гистограмму для более детального рассмотрения аномалий.

# %%
df['ceiling_height'].plot(kind='hist', bins=100,
                        title='Гистограмма распределения значений высоты потолков',
                        grid=True,
                        figsize=(7,3),
                        ylim=(0,10),
                        ylabel='ceiling_height',
                        fontsize=10)
df['ceiling_height'].sort_values().value_counts()
# Out:
# 2.50    3515
# 2.60    1646
# 2.70    1574
# 3.00    1112
# 2.80     993
#         ...
# 3.39       1
# 4.25       1
# 3.93       1
# 3.88       1
# 4.65       1
# Name: ceiling_height, Length: 183, dtype: int64

# %% [markdown]
# Природа пропусков не ясна, но оставить без внимания их нельзя, 40% это очень много, так как при дальнейшей обработке может потеряться большой объем данных. Причиной может быть:
# 1. Ошибки при выводе данных.
# 2. Не введенные значения.
# 3. Ошибки при вводе.
#
# Присутствуют аномалии, подробно изучу в разделе исследовательский анализ данных.
#
# Необходимо заменить пропушенные значения на типичные, таким может быть медиана или среднее. Выведу на экран список типичных значений, используя метод describe().

# %%
df['ceiling_height'].describe()
# Out:
# count    14504.000000
# mean         2.771499
# std          1.261056
# min          1.000000
# 25%          2.520000
# 50%          2.650000
# 75%          2.800000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Медиана и среднее отличаются, но не сильно 2,65 и 2,72 соответственно, можно использомать любое из них. Заполню пропуски медианой и проверю результат.

# %%
df['ceiling_height'] = df['ceiling_height'].fillna(df['ceiling_height'].median())
df['ceiling_height'].isna().sum()
# Out:
# 0

# %% [markdown]
# floors_total (всего этажей в доме) - 86 пропусков. Выведу уникальные значения столбца и их количество функцией value_counts().

# %%
df['floors_total'].value_counts()
# Out:
# 5.0     5788
# 9.0     3761
# 16.0    1376
# 12.0    1362
# 4.0     1200
# 10.0    1174
# 25.0    1075
# 6.0      914
# 17.0     833
# 3.0      668
# 7.0      592
# 14.0     553
# 18.0     505
# 24.0     469
# 8.0      390
# 2.0      383
# 15.0     365
# 23.0     352
# 19.0     339
# 22.0     286
# 20.0     271
# 13.0     229
# 11.0     203
# 27.0     164
# 21.0     158
# 26.0     124
# 1.0       25
# 35.0      24
# 28.0      21
# 36.0       3
# 37.0       1
# 34.0       1
# 33.0       1
# 60.0       1
# 29.0       1
# 52.0       1
# Name: floors_total, dtype: int64

# %% [markdown]
# Природа пропусков не ясна, возможно количество этажей не указано, так как этаж последний, подтвердить это невозможно, пропусков менее 1%, можно оставить их без изменения.
#
# Значение Nan имеет тип float, скорректировать тип данных не заполнив пропуски не получится.

# %% [markdown]
# living_area (жилая площадь) - 8% пропусков.
# Уникальные значения нет смысла выводить, так как их будет много, построю гистограмму и выведу характериные значения

# %%
df['living_area'].plot(kind='hist', bins=30,
                        title='Гистограмма распределения значений жилой площади',
                        grid=True,
                        figsize=(7,3),
                        fontsize=10)
plt.xlabel('kitchen_area')
plt.ylabel('frequency')
plt.show()
df['living_area'].describe()
# Out:
# count    21796.000000
# mean        34.457852
# std         22.030445
# min          2.000000
# 25%         18.600000
# 50%         30.000000
# 75%         42.300000
# max        409.700000
# Name: living_area, dtype: float64

# %% [markdown]
# Распределение близко к Пуассону. Есть слишком большие значения, но влияние их на выборку не велико, так как среднее и медиана расходятся не сильно.
#
# Припода пропусков не ясна, причиной могут быть ошибки при вводе или выводе данных.

# %% [markdown]
# Столбце is_apartment (апартаменты) - 89% пропусков. Выведу уникальные значения столбца.

# %%
df['is_apartment'].value_counts()
# Out:
# False    2725
# True       50
# Name: is_apartment, dtype: int64

# %% [markdown]
# Число заполненных значений в таблице не велико. Если почитать статьи, можно выяснить, что само понятие апартаментов было узаконенно в России в 2008-2009 гг., а система налогооблажения начала становиться в 2017, на основании этого можно предположить, что этот параметр долгое время не был включен в базы недвижимости или его не заполняли.
# Заполню пропуски значением False, и изменю тип на bool. Проверю результат.

# %%
df['is_apartment'] = df['is_apartment'].fillna(False).astype('bool')
df['is_apartment'].value_counts()
# Out:
# False    23649
# True        50
# Name: is_apartment, dtype: int64

# %% [markdown]
# kitchen_area (площадь кухни) - около 10% пропусков. Уникальные значения нет смысла выводить, так как их будет много, построю гистограмму и выведу характериные значения.

# %%
df['kitchen_area'].plot(kind='hist', bins=30,
                        title='Гистограмма распределения значений площади кухни',
                        grid=True,
                        figsize=(7,3),
                        fontsize=15)
plt.xlabel('kitchen_area')
plt.ylabel('frequency')
plt.show()
df['kitchen_area'].describe()
# Out:
# count    21421.000000
# mean        10.569807
# std          5.905438
# min          1.300000
# 25%          7.000000
# 50%          9.100000
# 75%         12.000000
# max        112.000000
# Name: kitchen_area, dtype: float64

# %% [markdown]
# Распределение близко к Пуассону. Есть слишком большие значения, но влияние их на выборку не велико, так как среднее и медиана расходятся не сильно.
#
# Припода пропусков не ясна, причиной могут быть ошибки при вводе или выводе данных.

# %% [markdown]
# balcony (число балконов) - около 50% пропусков. Выведу на экран уникальные значения столбца.

# %%
df['balcony'].value_counts()
# Out:
# 1.0    4195
# 0.0    3758
# 2.0    3659
# 5.0     304
# 4.0     183
# 3.0      81
# Name: balcony, dtype: int64

# %% [markdown]
# Аномалий в этом столбце не вижу, кроме типа данных, но это объяснимо пропусками.
#
# Скорее всего пропуски возникли, так как человек не вводил данные, если балконов нет. Заполню пропуски нулями и изменю типа данных на int. Проверю результат.

# %%
df['balcony'] = df['balcony'].fillna(0).astype('int')
df['balcony'].value_counts()
# Out:
# 0    15277
# 1     4195
# 2     3659
# 5      304
# 4      183
# 3       81
# Name: balcony, dtype: int64

# %% [markdown]
# Подозрительно одинаковое количество пропусков у столбцов:
# - airports_nearest	    5542	23%
# - city_сenters_neares	5519	23%
# - parks_around3000	    5518	23%
# - ponds_around3000	    5518	23%
#
# Пропуски в этих столбцах могут быть причиной в ошибке рассчета геолокации или отсутствием таковой, если это так, то все пропуски в одинаковых местах таблица, а также это может быть причиной части пропусков в столбцах:
# - parks_nearest	15620	65%
# - ponds_nearest	14589	61%
#
# Проверю это, сделаю фильтр по всем указанным параметрам (удобнее использовать loc) и посчитаю количество оставшихся строк по любому стобцу без пропусков.

# %%
print('Количество строк после фильтрации:',
(
    df.loc[df['airports_nearest'].isna()]
    .loc[df['city_сenters_neares'].isna()]
    .loc[df['parks_around3000'].isna()]
    .loc[df['ponds_around3000'].isna()]
    .loc[df['parks_nearest'].isna()]
    .loc[df['ponds_nearest'].isna()]['rooms'].count()
))
# Out:
# Количество строк после фильтрации: 5518

# %% [markdown]
# Пропуски в обинаковых строках, следовательно предположение подтвердилось: ошибки в геолокации.
#
# Объяснить оставшиеся пропуски в столбцах parks_nearest 10102 и ponds_nearest 9071 можно тем, что когда в райне 3км нет указанного объекта (ponds_around3000 и parks_around3000 равны 0) расчет расстояния до них не ведется.
#
# Проверю это вычислив число пропусков в столбцах ponds_around3000 и parks_around3000 при нулевых значениях parks_nearest и ponds_nearest.
# Использую фильтрацию методом query() и функцию value_counts с атрибутом dropna=False

# %%
print('Количество пропусков ponds_nearest при ponds_around3000 = 0:', 
      df.query('parks_around3000 == 0')['parks_nearest'].isna().sum())
print('Количество пропусков ponds_nearest при ponds_around3000 = 0:', 
      df.query('ponds_around3000 == 0')['ponds_nearest'].isna().sum())
# Out:
# Количество пропусков ponds_nearest при ponds_around3000 = 0: 10102
# Количество пропусков ponds_nearest при ponds_around3000 = 0: 9071

# %% [markdown]
# Предположение подтвердтлось, нужно обратить на это внимание в выводах. Заменить значения во всех этих столбцах нет возможности так как нет исходных данных об адресе, но и удалить их нельзя так как потеряется минимум 23% полезной информации из остальных стобцов.

# %%
df.query('city_сenters_neares != city_сenters_neares').head(10)
df.query('(city_сenters_neares != city_сenters_neares) and (airports_nearest != airports_nearest) and (parks_around3000 != parks_around3000) and (parks_nearest != parks_nearest) and (ponds_around3000 != ponds_around3000) and (ponds_nearest != ponds_nearest)')['ponds_nearest'].value_counts(dropna=False)
# Out:
# NaN    5518
# Name: ponds_nearest, dtype: int64

# %% [markdown]
# locality_name - название населенного пункта - 49 пропусков 0,2%. Столбец с котегориальными переменными, чтобы их заменить нужно знать исходные данные или проводить более глубокий анализ данных. Число пропусков не велико, поэтому оставлю их как есть.
#
# Просмотрю уникальные значения столбца на предмет аномалий, используя функцию unique().

# %%
df['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'посёлок Шушары', 'городской посёлок Янино-1',
#        'посёлок Парголово', 'посёлок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина', 'поселок Мурино',
#        'деревня Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'посёлок Металлострой',
#        'посёлок городского типа Лебяжье',
#        'посёлок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'посёлок Аннино',
#        'поселок городского типа Ефимовский', 'посёлок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
# ...

# %% [markdown]
# На первый взгляд неявных дубликатов не наблюдается. Аномалий не вижу.

# %% [markdown]
# days_exposition (сколько дней было размещено объявление) - 3181 пропусков 13%. Скорее всего, на месте пропущенных значений объявления, которые висели в продаже менее одного дня. Проверю это, выведу на экран количество объявлений с days_exposition = 0 к value_counts()

# %%
df.query('days_exposition == 0')['days_exposition'].value_counts()
# Out:
# Series([], Name: days_exposition, dtype: int64)

# %% [markdown]
# Значений 0 дней для продажи действительно нет. Но квартира не может продаваться за 0 дне.

# %% [markdown]
# Возможно, причину удастся выянить посмотрев зависимость количесва пропуска по годам. Посмотрю уникальные даты выставления объявлений на продажу в этих строках.

# %%
(
    pd.to_datetime(df['first_day_exposition'].loc[df['days_exposition'].isna()], format='%Y-%m-%dT%H:%M:%S')
    .dt.year.value_counts()
)
# Out:
# 2019    1796
# 2018     959
# 2017     271
# 2015      70
# 2016      67
# 2014      18
# Name: first_day_exposition, dtype: int64

# %% [markdown]
# Пропуски есть в дате продажи есть во все года, количество пропусков увеличивается с годом.
#
# Пропуски выглядят случайными, но природа пропущенных значений остается неизвестной, 13% это слишком большой объем данных, оставлю их без изменения.

# %%
#df['days_exposition'] = df['days_exposition'].fillna(df['days_exposition'].median())
#df['days_exposition'] = df['days_exposition'].astype('int')
#df['days_exposition'].isna().sum()

# %% [markdown]
# Приведу тип данных в столбце first_day_exposition к типу datetime. Для этого использую функцию to_datetime(). Округлю значения до дня, так как время в данных нулевое и для анализа не требуется.

# %%
df['first_day_exposition'] = (
    pd.to_datetime(df['first_day_exposition'], 
                   format='%Y-%m-%dT%H:%M:%S')
    .dt.round('1d')
)
df.head(3)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70          16.0         51.0      8         False  ...
# 1            2.65          11.0         18.6      1         False  ...
# 2            2.65           5.0         34.3      4         False  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0        0  Санкт-Петербург           18863.0
# 1          11.0        2   посёлок Шушары           12817.0
# 2           8.3        0  Санкт-Петербург           21741.0
#
#   city_сenters_neares  parks_around3000  parks_nearest  ponds_around3000  \
# 0             16028.0               1.0          482.0               2.0
# ...

# %% [markdown]
# В столбце last_price довольно большие числа, значения после запятой хранить нет смысла. Изменю тип данных этого слобца на int.

# %%
df['last_price'].astype('int')
# Out:
# 0        13000000
# 1         3350000
# 2         5196000
# 3        64900000
# 4        10000000
#            ...
# 23694     9700000
# 23695     3100000
# 23696     2500000
# 23697    11475000
# 23698     1350000
# Name: last_price, Length: 23699, dtype: int64

# %% [markdown]
# Просмотрю остальные столбца таблица на предмет аномальных значений.

# %%
df['total_images'].plot(kind='hist', bins=10,
                        title='Гистограмма распределения значений количества картинок',
                        grid=True,
                        figsize=(7,3),
                        fontsize=10)
plt.xlabel('total_images')
plt.ylabel('frequency')
plt.show()

# %%
df['rooms'].value_counts()
# Out:
# 1     8047
# 2     7940
# 3     5814
# 4     1180
# 5      326
# 0      197
# 6      105
# 7       59
# 8       12
# 9        8
# 10       3
# 11       2
# 14       2
# 19       1
# 16       1
# 12       1
# 15       1
# Name: rooms, dtype: int64

# %%
df['total_area'].value_counts()
# Out:
# 45.00     419
# 42.00     383
# 60.00     347
# 31.00     346
# 44.00     345
#          ...
# 44.24       1
# 56.85       1
# 37.92       1
# 115.60      1
# 55.06       1
# Name: total_area, Length: 2182, dtype: int64

# %%
df['floor'].value_counts()
# Out:
# 2     3368
# 3     3073
# 1     2917
# 4     2804
# 5     2621
# 6     1305
# 7     1218
# 8     1083
# 9     1051
# 10     687
# 12     526
# 11     523
# 13     379
# 15     343
# 14     337
# 16     315
# 17     227
# 18     178
# 19     147
# 21     125
# 22     113
# 20     110
# 23     100
# 24      63
# 25      46
# 26      24
# 27      10
# 28       1
# 29       1
# 32       1
# 30       1
# 33       1
# 31       1
# Name: floor, dtype: int64

# %%
df['studio'].value_counts()
# Out:
# False    23550
# True       149
# Name: studio, dtype: int64

# %%
df['open_plan'].value_counts()
# Out:
# False    23632
# True        67
# Name: open_plan, dtype: int64

# %% [markdown]
# В столбцах total_images, total_area, rooms, floor, studio, open_plan аномалий не выявлено.

# %% [markdown]
# ### Удаление дубликатов.

# %% [markdown]
# Возможные аномалии в данных были мной исправлены на предидущем этапе исследования. Проверю есть ли явные дубликаты в таблице, используя функции duplicated() и sum().

# %%
print('Количество явных дубликатов:', df.duplicated().sum())
# Out:
# Количество явных дубликатов: 0

# %% [markdown]
# Дубликаты отсутствуют. Можно продолжать работу над проектом.

# %% [markdown]
# ### Выводы.

# %% [markdown]
# По итогам предобработки данных можно сделать следующие выводы:
# 1. Названия столбцов приведены в соответствие с "змеиным_регистром".
# 2. Были определены и заполнены пропуски, где это уместно.
# 3. Заменены типы данных в некоторых столбцах.
# 4. Большая часть пропусков (до 50%) не была заполнена, так как в некоторых столбцах для этого недостаточно данных. Но, так как в дальнейшем нужно анализировать влияние каждого параметра в отдельности на цену число пропусков во всех столбцах вместе не будет играть роли. Соответственно для анализа остается достаточное количество данных.
# 5. Есть проблема с расчетом количества дней, не расчитывается или не выводится количество дней 0.
# 6. Есть проблема с расчетом показателей геолокации, нужно проверить эти данные не вводились или не были рассчитаны.
# 7. Проведена проверка на ановалии и дубликаты.

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %% [markdown]
# В чистом виде табличные данные некоторых столбцов бесполезны. Их необходимо преобразовать и добавить нужную информацию.
#
# Посчитано и добавлю в таблицу: цена квадратного метра. Проверю результат.

# %%
df['price_square_meter'] = (df['last_price'] / df['total_area']).astype('int')
display(df.head(3))
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70          16.0         51.0      8         False  ...
# 1            2.65          11.0         18.6      1         False  ...
# 2            2.65           5.0         34.3      4         False  ...
#
#    balcony    locality_name  airports_nearest  city_сenters_neares  \
# 0        0  Санкт-Петербург           18863.0              16028.0
# 1        2   посёлок Шушары           12817.0              18603.0
# 2        0  Санкт-Петербург           21741.0              13933.0
#
#   parks_around3000  parks_nearest  ponds_around3000  ponds_nearest  \
# ...

# %% [markdown]
# Посчитаю и добавлю в таблицу: день недели, месяц и год публикации объявления. Выведу на экран первые строки таблицы для проверки.

# %%
df['weekday'] = df['first_day_exposition'].dt.weekday
df['month'] = df['first_day_exposition'].dt.month
df['year'] = df['first_day_exposition'].dt.year
df.head(3)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70          16.0         51.0      8         False  ...
# 1            2.65          11.0         18.6      1         False  ...
# 2            2.65           5.0         34.3      4         False  ...
#
#    city_сenters_neares  parks_around3000  parks_nearest  ponds_around3000  \
# 0              16028.0               1.0          482.0               2.0
# 1              18603.0               0.0            NaN               0.0
# 2              13933.0               1.0           90.0               2.0
#
#   ponds_nearest  days_exposition  price_square_meter  weekday  month  year
# ...

# %% [markdown]
# Посчитаю и добавлю в таблицу: категоризацию этажей квартиры; первый, последний, другой. Для этого использую метод where(). Выведу уникальные значения и первые строки таблицы для проверки.

# %%
df['floor_category'] = df['floors_total'].where(~((df['floors_total'] > df['floor']) & (df['floor'] > 1)), 'Другой')
df['floor_category'] = df['floor_category'].where(df['floors_total'] != df['floor'], 'Последний')
df['floor_category'] = df['floor_category'].where(df['floor'] != 1, 'Первый')
print('Уникальные значения floor_category:', df['floor_category'].unique())
df.head(3)
# Out:
# Уникальные значения floor_category: ['Другой' 'Первый' 'Последний' nan]
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70          16.0         51.0      8         False  ...
# 1            2.65          11.0         18.6      1         False  ...
# 2            2.65           5.0         34.3      4         False  ...
#
#    parks_around3000  parks_nearest  ponds_around3000  ponds_nearest  \
# 0               1.0          482.0               2.0          755.0
# 1               0.0            NaN               0.0            NaN
# 2               1.0           90.0               2.0          574.0
#
# ...

# %% [markdown]
# Посчитано и добавлею в таблицу: соотношение жилой и общей площади (total_kitchen_area), а также отношение площади кухни к общей (total_living_area). Выведу на экран первые строки таблицы для проверки.

# %%
df['total_kitchen_area'] = df['kitchen_area'] / df['total_area'] 
df['total_living_area'] = df['living_area'] / df['total_area'] 
df.head(3)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70          16.0         51.0      8         False  ...
# 1            2.65          11.0         18.6      1         False  ...
# 2            2.65           5.0         34.3      4         False  ...
#
#    ponds_around3000  ponds_nearest  days_exposition  price_square_meter  \
# 0               2.0          755.0              NaN              120370
# 1               0.0            NaN             81.0               82920
# 2               2.0          574.0            558.0               92785
#
#   weekday  month  year  floor_category  total_kitchen_area  total_living_area
# ...

# %% [markdown]
# ### Выводы

# %% [markdown]
# Расчитана и добавлена в таблицу недостающая информация.
#
# Необходимо исследовать влияние параметров на цену квадратного метра.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Дополнительное исследование: площадь (относительная), цена, число комнат, высота потолков

# %% [markdown]
# Важными параметрами являются: площадь, цена, число комнат, высота потолков. Их необходимо дополнительно изучить.
#
# Построю гистограмму для относительных площадей квартиры (total_kitchen_area и total_living_area), выведу характерные значения для них, проверю, что значения распределены ожидаемым образом.

# %%
ax = df['total_kitchen_area'].plot(
    kind='hist',
    histtype='step',
    bins=25,
    linewidth=5,
    alpha=0.7,
    label='total_kitchen_area',
    legend=True
) 
df['total_living_area'].plot(
    kind='hist',
    histtype='step',
    bins=25,
    linewidth=5,
    alpha=0.7,
    label='total_living_area',
    ax=ax,
    grid=True,
    legend=True,
    figsize=(7,3)
) 
plt.xlabel('area')
plt.ylabel('frequency')
plt.title('Гистограмма распределения значений относительной площади')
plt.show()
display(pd.concat([df['total_kitchen_area'].describe(), df['total_living_area'].describe()], axis=1))
# Out:
#        total_kitchen_area  total_living_area
# count        21421.000000       21796.000000
# mean             0.187355           0.564766
# std              0.072968           0.105368
# min              0.025381           0.021583
# 25%              0.133333           0.495177
# 50%              0.172414           0.567860
# 75%              0.232416           0.637880
# max              0.787879           1.000000

# %% [markdown]
# Распределение параметров total_kitchen_area и total_living_area близко к Пуассону, total_living_area болше стренится к нормальному. Вид гистограмм примимает ожидаемый вид:
# - С увеличением относительной площади кухни уменьшается относительная жилая площади.
# - Пиковая относительная площадь кухни существенно ниже пиковой относительной жилой площади.
# - Резких выбросов и аномальных значений не наблюдается.
#
# Среднее значение и медиана для обеих величин практически не расходятся. Можно считать, что с данными все в порядке.

# %% [markdown]
# Выведу на экран характерные значения для стобцов: общая площадь - total_area, цена - last_price, количество комнат - rooms, высота потолков - ceiling_height.

# %%
display(pd.concat([df['total_area'].describe(), 
                   df['last_price'].describe(),
                   df['rooms'].describe(),
                   df['ceiling_height'].describe()], axis=1))
# Out:
#          total_area    last_price         rooms  ceiling_height
# count  23699.000000  2.369900e+04  23699.000000    23699.000000
# mean      60.348651  6.541549e+06      2.070636        2.724358
# std       35.654083  1.088701e+07      1.078405        0.988298
# min       12.000000  1.219000e+04      0.000000        1.000000
# 25%       40.000000  3.400000e+06      1.000000        2.600000
# 50%       52.000000  4.650000e+06      2.000000        2.650000
# 75%       69.900000  6.800000e+06      3.000000        2.700000
# max      900.000000  7.630000e+08     19.000000      100.000000

# %% [markdown]
# По предварительным данным можно сделать следующие выводы:
# 1. Общая площадь распределяется в пределах от 12 до 900 м.кв. Среднее значение и медиана расходятся незначительно, выбросы не оказывают существенного влияния.
# 2. Цена изменяется в пределах от 12 тыс. до 763 млн. Среднее значение и медиана расходятся незначительно, выбросы не оказывают существенного влияния.
# 3. Количество комнат изменяется в пределах от 0 (могут быть студии) до 19 (могут быть коммуналки). Среднее значение и медиана расходятся незначительно, выбросы не оказывают существенного влияния.
# 4. Высота потолков изменяется в пределах от 1 до 100. Аномальные значения присутствуют, но среднее значение и медиана расходятся незначительно и имеют приемлемое значение (2,7 м), выбросы не оказывают существенного влияния.
# 5. Все выбросы и аномальные значения выглядят как эксклюзивные предложения, хоть они не оказывают влияния на выборку необходимо определить корректные границы для построения гистограмм.
#
# Построю диаграмму размаха для каждой величины.

# %%
fig, axes = plt.subplots(2, 2, figsize=(50,25))
titles = ['Диаграмма размаха площади', 'Диаграмма размаха цен',
         'Диаграмма размаха количества комант', 'Диаграмма размаха высоты полоков']
columns = ['total_area', 'last_price', 'rooms', 'ceiling_height']

ylims = [300, 2e7, 10, 5]
count = 0
for row in range(2):
    for col in range(2):
        ax = df.boxplot(column=columns[count], ax=axes[row,col], fontsize=35)
        ax.set_ylim([0, ylims[count]])
        ax.set_title(titles[count], fontsize=35)
        count += 1

# %% [markdown]
# Пределы для дальнейших расчетов:
# 1. Общая площадь - от 15 до 115 м.кв.
# 2. Цена - от 12 тыс. до 12 млн.
# 3. Количество комнат - от 0 до 6.
# 4. Высота потолков - от 2,2 до 3,2 м.
#
# Построю гистограммы для выбранных пределов

# %%
fig, axes = plt.subplots(4, 2, figsize=(50,25))
titles = [['Гистограмма по площади вблизи', 'Гистограмма по площади'],
         ['Гистограмма по цене вблизи', 'Гистограмма по цене'],
         ['Гистограмма по количеству комнат вблизи', 'Гистограмма по количеству комнат'],
         ['Гистограмма по высоте потолков вблизи', 'Гистограмма по высоте потолков']]
columns = ['total_area', 'last_price', 'rooms', 'ceiling_height']
lims_min = [15, 12e3, 0, 2]
lims_max = [200, 3e7, 6, 5]
binses = [25, 50, 4, 10]

for row in range(4):
    ax = df[columns[row]].plot(
        kind='hist',
        bins=binses[row],
        range=(lims_min[row], lims_max[row]),
        title=titles[row][0],
        xlabel=columns[row],
        ylabel='frequency',
        ax=axes[row,0],
        grid=True,
        fontsize=15,
        figsize=(20,20)
    )
    ax.title.set_size(20)
    ax = df[columns[row]].plot(
        kind='hist',
        bins=100,
        title=titles[row][1],
        xlabel=columns[row],
        ylabel='frequency',
        ax=axes[row,1],
        grid=True,
        fontsize=15,
        figsize=(20,20)
    )
    ax.title.set_size(20)

# %% [markdown]
# Выводы:
# 1. Основная выборка общей площади квартир лежит в диапазоне от 30 до 90 м.кв. Есть выбросы, но они незначительны.
# 2. Подавляющее большинство цен на квартиры лежат в диапазоне 2 до 12 млн. Большие и малые значения присутствуют, но их вляние не велико.
# 3. Самое большое количество предложний по количеству комнат - (1..3). Аномалии есть, но их количесво гораздо меньше.
# 4. Самые популярные высоты потолов - (2,5...2,7) и (3...3,2)м. Также есть аномальные значения, но влияние на основную группу они не оказывают.

# %% [markdown]
# ### Исследование времени продажи квартир

# %% [markdown]
# Построю гистограмму и выведу характериные значения для времени продажи квартир.

# %%
df['days_exposition'].plot(kind='hist', bins=100,
                        title='Гистограмма распределения значений по дням размещения',
                        grid=True,
                        figsize=(15,5),
                        fontsize=10)

plt.ylabel('frequency')
plt.show()
df['days_exposition'].describe()
# Out:
# count    20518.000000
# mean       180.888634
# std        219.727988
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        232.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Выявлены следующие аномалии:
# 1. Распределение изменения значений экспоненциально уменьшающийся, не похоже на нормальное распределение.
# 2. Диапазон изменения значений - от 1 до 1580 дней больше 4 лет (неправдоподобно большой разброс, много выбросов).
# 4. Присутствует 3 ярко выраженных пика в диапазоне от 20 до 100.
# 5. Медиана и среднее отличаются в 2 раза, 95 и 180 соответственно, влияние выбросов велико.
#
# Необходимо убрать аномально большие и малые значения. Чтобы определить границу построю диаграмму размаха.

# %%
df.boxplot('days_exposition', figsize=(3, 7)) 
plt.ylim(-10, 550)
plt.title('Диаграмма размаха по дням', fontsize=12)
plt.show()

# %% [markdown]
# Верхнюю границе можно определить как 520.
#
# Над нижней границей нужно подумать. Посмотрю по-подробнее диапазон от 20 до 100, в котором есть пиковые значения.

# %%
df['days_exposition'].plot(kind='hist', 
                           bins=160, 
                           range=(20, 100), 
                           title='Гистограмма распределения значений по дням размещения',
                           grid=True,
                           figsize=(15,5),
                           fontsize=10)

plt.ylabel('frequency')
plt.show()

# %% [markdown]
# Присутствуют ярко выреженные пики на 30, 45, 60 и 90 днях, в периоде 15, как-будто эти объявления были удавлены автоматически через какой-то период без подтверждения. Если объявления были сняты с продажи автоматически, значит квартира была продана раньше или не продана вовсе, от этих значений лучше избавиться. Но наверняка я не знаю природу этих значний, они лежат в пределах основной выборки. Оставлю их для дальнейшего анализа, но сделаю акцент в общих выводах на этой аномалии.
#
# Предлагаю установить нижнюю границу 20 дней.
#
# Отфильтрую данные по времени продажи и параметрам, найденным на предидущем этапе, расширю диапазоны так, чтобы сохранить большую часть информации:
#
# 1. По времени продажи квартиры от 10 до 1000 и включу в рассмотрение не проданные квартиры.
# 2. По общей площади - от 15 до 200 м.кв.
# 3. По цене - от 12 тыс. до 30 млн.
# 4. По количеству комнат - от 0 до 6.
# 5. По высоте потолков потолков - от 2 до 3,5 м.

# %%
df_filtered = df.query('((days_exposition >= 10) and (days_exposition <= 1000)) or (days_exposition != days_exposition)')
df_filtered = df_filtered.query('(total_area >= 15) and (total_area <= 200)')
df_filtered = df_filtered.query('(last_price >= 12e4) and (last_price <= 30e6)')
df_filtered = df_filtered.query('(rooms >= 0) and (rooms <= 6)')
df_filtered = df_filtered.query('(ceiling_height >= 2) and (ceiling_height <= 3.5)')

df_filtered['days_exposition'].plot(kind='hist', bins=100, 
                                    title='Гистограмма распределения значений по дням размещения',
                                    grid=True,
                                    figsize=(15,5),
                                    fontsize=10)

plt.ylabel('frequency')
plt.show()
print('Процент выборки для анализа:', 
      round((df_filtered['ceiling_height'].count() / df['ceiling_height'].count() * 100), 2), '%')
df_filtered['days_exposition'].describe()
# Out:
# Процент выборки для анализа: 91.37 %
# count    18635.000000
# mean       175.086021
# std        187.386688
# min         10.000000
# 25%         45.000000
# 50%        102.000000
# 75%        231.000000
# max       1000.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Выводы:
# - Определены границы времени продажи квартир: 20-520 дней;
# - Данные отфильтрованы, резкие выбросы удалены;
# - После фильтрации осталось 91,37% значений, достаточно для анализа;
# - Распределение постоянно убывающее, подавляющее большинство квартир продается в первые 200 дней размещения объявления, это похоже на правду;
# - Так как распределение не похоже на нормальное среднне и медиана расходятся, 175 и 102 соответственно. В расчетах следует руководствоваться медианой;
# - Обнаружены выбросы в районе 30, 45, 60 и 90 дней. Нужно разобраться в природе их появления.

# %% [markdown]
# ###  Зависимость цены от площади, удаленности от центра, числа комнат, этажа, удалённости от центра и даты размещения.

# %% [markdown]
# Исследование зависимости цены от площади. Сгруппирую выборку значений по 10 квадратных метров, найду медиану цен в этих диапазонах. Выведу график полученной зависимоти.

# %%
df_filtered['total_area_category'] = round(df_filtered['total_area']/10)
(
    df_filtered
    .groupby('total_area_category')['last_price'].median()
    .plot(y='last_price', x='total_area', xlabel='total_area / 10', ylabel='last_price',
          title='Зависимость цены от площади на каждые 10 м.кв.',
          grid=True, linewidth=2, style='o-', figsize=(7,5))
)
plt.show()

# %% [markdown]
# Исследование зависимости цены удаленности от центра. Сгруппирую выборку значений по 10 километров, найду медиану цен в этих диапазонах. Выведу график полученной зависимоти.

# %%
df_filtered['сenters_neares_category'] = round(df_filtered['city_сenters_neares']/10000)
(
    df_filtered.groupby('сenters_neares_category')['last_price'].median()
    .plot(y='last_price', x='сenters_neares_category', xlabel='сenters_neares / 10000', ylabel='last_price',
          title='Зависимость цены \n от растояния до центра на каждые 10 км',
          grid=True, linewidth=2, style='o-', figsize=(7,5))
)
plt.show()

# %% [markdown]
# Исследование зависимости цены от этажа. Ранее уже были введены категории этажей - первый, последнай и другой. Сгруппирую данные и построю столбчатую диаграмму.

# %%
(
    df_filtered.groupby('floor_category')['last_price'].median()
    .plot(y='last_price', xlabel='floor_category', kind='bar', 
          grid=True, linewidth=2, style='o-', figsize=(7,5))
)
plt.title('Зависимость цены от этажа')
plt.ylabel('last_price')
plt.show()

# %% [markdown]
# Исследование зависимости цены от количества комнат. Сгруппирую данные и построю столбчатую диаграмму.

# %%
(
    df_filtered.query('rooms <= 6')
    .groupby('rooms')['last_price'].median()
    .astype('int')
    .plot(y='last_price', xlabel='rooms', kind='bar',
          grid=True, linewidth=2, style='o-', figsize=(7,5))
)
plt.title('Зависимость цены от количества комнат')
plt.ylabel('last_price')
plt.show()

# %% [markdown]
# Исследование зависимости цены от даты размещения объявления. Сгруппирую данные по дням недели, месяцу и году, Выведу для каждой зависимости столбчатые диаграммы.

# %%
columns = ['weekday', 'month', 'year']
titles = ['Зависимость цены от дня недели', 
          'Зависимость цены от месяца', 
          'Зависимость цены от года']
count = 0
for name in columns:
    (
        df_filtered
        .groupby(name)['last_price'].median()
        .plot(y='last_price', xlabel=name, kind='bar', 
         grid=True, linewidth=2, style='o-', figsize=(7,5))
    )
    plt.title(titles[count])
    plt.ylabel('last_price')
    plt.show()
    count += 1

# %% [markdown]
# Выводы:
#
# Зависимость от площади квартиры.
# - По графику наблюдается практически прямая зависимость цены от площади.
# - С ростом площади растет цена квартир.
# - Диапазон изменения значений от 2 до 20 млн.
# - Есть спад цен в районе 170 кв.м., но это скорее аномалия.
#
# Зависимость от удаленности от центра.
# - По графику наблюдается обратная зависимость цены от растояния от центра.
# - Самая высокая стоимость в пределах первых 10 км - 9млн., далее график резко падает до 5,2 млн. и плавно спадает до 3,2 млн.
#
# Зависимость от этажа размещения.
# - Самая высокая цена квартир для категории этажей другой - 4,8 млн.
# - Долее последний этаж - 4,2 млн.
# - Самые дешевые квартиры на первом этаже - 3,8 млн.
#
# Зависимость от количества комнат.
# - Наблюдается прямая зависимость.
# - Цена растет от 2,5 млн для квартик студий (0 комнат) до 11 млн для 6-комнатных квартир.
#
# Зависимость от даты размещения:
# - От дня недели зависимоти на наблюдается.
# - От месяца размещения зависимоти не наблюдается. Наблюдаются спады в 6 месяце (июнь).
# - От года размещения зависимость есть. Самая высокая цена была в 2014 году - 7,5 млн., долее резкой спад к 2016 года - 4,4 млн. и плавный рост цен до 2019 года до 5 млн.

# %% [markdown]
# ### Исследование цен в населенных пунктах

# %% [markdown]
# Сгруппирую данные по названию населенных пунктов, посчитаю медианную цену квартир для каждого из них. Выберу и выведу на экран 10 городов с наибольшим количеством объявлений.

# %%
locality_name_pivot = (
    df_filtered.pivot_table(index=['locality_name'], 
                            values='price_square_meter', 
                            aggfunc=['median','count'])
)
locality_name_pivot.columns = ['price_square_meter', 'count']
locality_name_pivot = (
    locality_name_pivot
    .sort_values(by='count', ascending=False)
)
city_top = df_filtered['locality_name'].value_counts().index[:10]
locality_name_pivot = locality_name_pivot.query('locality_name in @city_top')
display(locality_name_pivot)
# Out:
#                    price_square_meter  count
# locality_name
# Санкт-Петербург              104166.0  14123
# посёлок Мурино                86231.0    481
# посёлок Шушары                76876.0    418
# Всеволожск                    65843.0    380
# Пушкин                        99993.5    336
# Колпино                       74468.0    315
# посёлок Парголово             91337.0    304
# Гатчина                       67796.0    289
# деревня Кудрово               91666.0    277
# Выборг                        58133.0    224

# %% [markdown]
# Выводы:
# - Наименьшая цена квадратного метра в Выборге 56221.
# - Наибольшая цена квадратного метра в Санкт-Петербурге 102941
# - Получен ожидаемый результат: наибольшая цена в пределах города, далее в Лен.области тенденция к снижению.

# %% [markdown]
# ### Исследование расстояния до центра

# %% [markdown]
# Для проверки результатов и более тонкого анализа необходимо провести проверку по отдельной категории квартир.
#
# Исследую цену квадратного метра жилья по удаленности от центра:
# - Сгруппирую данные по удаленности в категории по 1 км.
# - Отфильтрую данные в пределах Санкт-Петербурга.
# - Выведу гистограмму медианы цен для каждой категории.

# %%
df['сenters_neares_delta_km'] = round(df['city_сenters_neares']/1000)
df_spb_pivot = (
    df
    .query('locality_name == "Санкт-Петербург"')
    .pivot_table(index='сenters_neares_delta_km', values='price_square_meter', aggfunc=['median']))
df_spb_pivot.columns = ['price_square_meter']
df_spb_pivot.plot(y='price_square_meter', xlabel='сenters_neares_delta_km', kind='bar',
                  grid=True, linewidth=2, style='o-', figsize=(15,5), fontsize=10)
plt.title('Зависимость цены квадратного метра жилья от растояния до центра на каждый километр')
plt.ylabel('price_square_meter')
plt.show()

# %% [markdown]
# Выводы:
# - Наблюдается резкий спад цен около 3 и 8 км.
# - Выше 8 км плавное снижение цен. Есть выброс на 27 км., но это скорее аномальное значение, чем показатель.
# - Пределом центра города по графику можно считать 8 км.

# %% [markdown]
# ### Иследование влияния основнях параметров на цену квартир в центральном районе

# %%
df_centre = df.query('сenters_neares_delta_km <= 8')
df_centre.head(3)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 3              0  64900000.0       159.0           2015-07-24      3
# 4              2  10000000.0       100.0           2018-06-19      2
# 24             8   6500000.0        97.2           2015-10-31      2
#
#     ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 3             2.65          14.0          NaN      9         False  ...
# 4             3.03          14.0         32.0     13         False  ...
# 24            2.65           3.0         46.5      1         False  ...
#
#     ponds_nearest  days_exposition  price_square_meter  weekday month  year  \
# 3           234.0            424.0              408176        4     7  2015
# 4            48.0            121.0              100000        1     6  2018
# 24          124.0            265.0               66872        5    10  2015
#
#     floor_category  total_kitchen_area  total_living_area  \
# ...

# %% [markdown]
# Выведу на экран характерные значения для стобцов: общая площадь - total_area, цена - last_price, количество комнат - rooms, высота потолков - ceiling_height.

# %%
display(pd.concat([df_centre['total_area'].describe(), 
                   df_centre['last_price'].describe(),
                   df_centre['rooms'].describe(),
                   df_centre['ceiling_height'].describe()], axis=1))
# Out:
#         total_area    last_price        rooms  ceiling_height
# count  4140.000000  4.140000e+03  4140.000000     4140.000000
# mean     90.282072  1.415791e+07     2.757971        2.962884
# std      58.791790  2.353420e+07     1.424214        1.724841
# min      12.000000  1.600000e+06     0.000000        2.000000
# 25%      55.000000  6.450000e+06     2.000000        2.650000
# 50%      76.000000  8.950000e+06     3.000000        2.800000
# 75%     107.000000  1.390000e+07     3.000000        3.100000
# max     900.000000  7.630000e+08    19.000000      100.000000

# %% [markdown]
# По предварительным данным можно сделать следующие выводы:
# 1. Общая площадь распределяется в пределах от 12 до 900 м.кв. Среднее значение и медиана расходятся незначительно, выбросы не оказывают существенного влияния.
# 2. Цена изменяется в пределах от 1.6 млн. до 763 млн. Среднее значение и медиана расходятся незначительно, выбросы не оказывают существенного влияния.
# 3. Количество комнат изменяется в пределах от 0 до 19. Среднее значение и медиана расходятся незначительно, выбросы не оказывают существенного влияния.
# 4. Высота потолков изменяется в пределах от 2 до 100. Аномальные значения присутствуют, но среднее значение и медиана расходятся незначительно и имеют приемлемое значение (3 м), выбросы не оказывают существенного влияния.
# 5. Все выбросы и аномальные значения выглядят как эксклюзивные предложения, хоть они не оказывают влияния на выборку необходимо определить корректные границы для построения гистограмм.
#
# Построю диаграмму размаха для каждой величины.

# %%
fig, axes = plt.subplots(2, 2, figsize=(50,25))
columns = ['total_area', 'last_price', 'rooms', 'ceiling_height']
titles = ['Диаграмма размаха площади', 'Диаграмма размаха цен',
         'Диаграмма размаха количества комант', 'Диаграмма размаха высоты потолков']
ylims = [300, 4e7, 10, 5]
count = 0
for row in range(2):
    for col in range(2):
        ax = df_centre.boxplot(column=columns[count], ax=axes[row,col], fontsize=35)
        ax.set_ylim([0, ylims[count]])
        ax.set_title(titles[count], fontsize=35)
        count += 1

# %% [markdown]
# Пределы для дальнейших расчетов:
# 1. Общая площадь - от 15 до 180 м.кв.
# 2. Цена - от 2.3 млн. до 25 млн.
# 3. Количество комнат - от 1 до 4.
# 4. Высота потолков - от 2,5 до 3,5 м.
#
# Построю гистограммы для выбранных пределов

# %%
fig, axes = plt.subplots(4, 2, figsize=(50,25))
columns = ['total_area', 'last_price', 'rooms', 'ceiling_height']
titles = [['Гистограмма по площади вблизи', 'Гистограмма по площади'],
         ['Гистограмма по цене вблизи', 'Гистограмма по цене'],
         ['Гистограмма по количеству комнат вблизи', 'Гистограмма по количеству комнат'],
         ['Гистограмма по высоте потолков вблизи', 'Гистограмма по высоте потолков']]
lims_min = [15, 2.3e6, 1, 2.4]
lims_max = [200, 3e7, 4, 5]
binses = [25, 50, 4, 10]

for row in range(4):
    ax = df_centre[columns[row]].plot(
        kind='hist',
        bins=binses[row],
        range=(lims_min[row], lims_max[row]),
        title=titles[row][0],
        xlabel=columns[row],
        ylabel='frequency',
        ax=axes[row,0],
        grid=True,
        fontsize=15,
        figsize=(20,20)
    )
    ax.title.set_size(20)
    ax = df_centre[columns[row]].plot(
        kind='hist',
        bins=200,
        title=titles[row][1],
        xlabel=columns[row],
        ylabel='frequency',
        ax=axes[row,1],
        grid=True,
        fontsize=15,
        figsize=(20,20)
    )
    ax.title.set_size(20)

# %% [markdown]
# Выводы:
# 1. Основная выборка общей площади квартир лежит в диапазоне от 30 до 125 м.кв. Есть выбросы, но они незначительны.
# 2. Подавляющее большинство цен на квартиры лежат в диапазоне 20 до 15 млн. Большие и малые значения присутствуют, но их вляние не велико.
# 3. Самое большое количество предложний по количеству комнат - (2..3). Аномалии есть, но их количесво гораздо меньше.
# 4. Самые популярные высоты потолов - (2,7) и (3...3,2)м. Также есть аномальные значения, но влияние на основную группу они не оказывают.

# %% [markdown]
# Построю гистограмму и выведу характериные значения для времени продажи квартир.

# %%
df_centre['days_exposition'].plot(kind='hist', bins=100, 
                                  title='Гистограмма распределения значений по дням размещения',
                                  grid=True,
                                  figsize=(15,5),
                                  fontsize=10)

plt.ylabel('frequency')
plt.show()
df_centre['days_exposition'].describe()
# Out:
# count    3476.000000
# mean      241.413982
# std       270.900326
# min         3.000000
# 25%        60.000000
# 50%       136.000000
# 75%       335.000000
# max      1572.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Выявлены следующие аномалии:
# 1. Распределение изменения значений экспоненциально уменьшающийся, не похоже на нормальное распределение.
# 2. Диапазон изменения значений - от 1 до 1580 дней больше 4 лет (неправдоподобно большой разброс, много выбросов).
# 4. Присутствует 3 ярко выраженных пика в диапазоне от 20 до 100.
# 5. Медиана и среднее отлтчаются в 2 раза, 95 и 180 соответственно, влияние выбросов велико.
#
# Необходимо убрать аномально большие и малые значения. Чтобы определить границу построю диаграмму размаха.

# %%
df_centre.boxplot('days_exposition', figsize=(3, 7)) 
plt.ylim(-10, 800)
plt.title('Диаграмма размаха \n по дням', fontsize=12)
plt.show()

# %% [markdown]
# Предлагаю установить нижнюю границу 50 дней, а верхнюю 750.
# Фильтровать данные буду в расширенных дипазонах, так, чтобы от исходного датасета по центрк города осталось не менее 90% данных.

# %%
df_filtered_centre = (
    df_centre.query('((days_exposition >= 10) and (days_exposition <= 1200)) or (days_exposition != days_exposition)')
)
df_filtered_centre = df_filtered_centre.query('(total_area >= 15) and (total_area <= 250)')
df_filtered_centre = df_filtered_centre.query('(last_price >= 12e4) and (last_price <= 50e6)')
df_filtered_centre = df_filtered_centre.query('(rooms >= 0) and (rooms <= 6)')
df_filtered_centre = df_filtered_centre.query('(ceiling_height >= 2) and (ceiling_height <= 4.5)')


df_filtered_centre['days_exposition'].plot(kind='hist', bins=100, 
                                           title='Гистограмма распределения значений по дням размещения',
                                           grid=True,
                                           figsize=(15,5),
                                           fontsize=10)

plt.ylabel('frequency')
plt.show()
print('Процент выборки для анализа:', 
      round((df_filtered_centre['ceiling_height'].count() / df_centre['ceiling_height'].count() * 100), 2), '%')
df_filtered_centre['days_exposition'].describe()
# Out:
# Процент выборки для анализа: 90.27 %
# count    3122.000000
# mean      235.364510
# std       244.311524
# min        10.000000
# 25%        60.000000
# 50%       141.500000
# 75%       330.750000
# max      1182.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Выводы:
# - Определены границы времени продажи квартир: 50-750 дней;
# - Данные отфильтрованы, резкие выбросы удалены;
# - После фильтрации осталось 90.27% значений от исходного;
# - Распределение постоянно убывающее, подавляющее большинство квартир продается в первые 200 дней размещения объявления, это похоже на правду;
# - Так как распределение не похоже на нормальное среднне и медиана расходятся, 235 и 141 соответственно. В расчетах следует руководствоваться медианой;
# - Обнаружены выбросы с периодичностью в 15 дней.

# %% [markdown]
# Проведу исследование влияния основных параметров аналогично расчету для всех населенных пунктов.
# Исследование зависимости цены от площади.

# %%
df_filtered_centre['total_area_category'] = round(df_filtered_centre['total_area']/10)
(
    df_filtered_centre
    .groupby('total_area_category')['last_price'].median()
    .plot(y='last_price', x='total_area', xlabel='total_area / 10', ylabel='last_price',
          title='Зависимость цены от площади на каждые 10 м.кв.',
          grid=True, linewidth=2, style='o-', figsize=(7,5))
)
plt.show()

# %% [markdown]
# Исследование зависимости цены удаленности от центра.

# %%
(
    df_filtered_centre.groupby('сenters_neares_delta_km')['last_price'].median()
    .plot(y='last_price', x='сenters_neares_delta_km', xlabel='сenters_neares / 1000', ylabel='last_price',
          title='Зависимость цены \n от растояния до центра на каждый километр',
          grid=True, linewidth=2, style='o-', figsize=(7,5))
)
plt.show()

# %% [markdown]
# Исследование зависимости цены от этажа.

# %%
(
    df_filtered_centre.groupby('floor_category')['last_price'].median()
    .plot(y='last_price', xlabel='floor_category', kind='bar',
          grid=True, linewidth=2, style='o-', figsize=(7,5))
)
plt.title('Зависимость цены от этажа')
plt.ylabel('last_price')
plt.show()

# %% [markdown]
# Исследование зависимости цены от количества комнат.

# %%
(
    df_filtered_centre
    .groupby('rooms')['last_price'].median()
    .astype('int')
    .plot(y='last_price', xlabel='rooms', kind='bar',
          grid=True, linewidth=2, style='o-', figsize=(7,5))
)
plt.title('Зависимость цены от количества комнат')
plt.ylabel('last_price')
plt.show()

# %% [markdown]
# Исследование зависимости цены от даты размещения объявления. Сгруппирую данные по дням недели, месяцу и году, Выведу для каждой зависимости столбчатые диаграммы.

# %%
columns = ['weekday', 'month', 'year']
titles = ['Зависимость цены от дня недели', 
          'Зависимость цены от месяца', 
          'Зависимость цены от года']
count = 0
for name in columns:
    (
        df_filtered_centre
        .groupby(name)['last_price'].median()
        .plot(y='last_price', xlabel=name, kind='bar', 
         grid=True, linewidth=2, style='o-', figsize=(7,5))
    )
    plt.title(titles[count])
    plt.ylabel('last_price')
    plt.show()
    count += 1

# %% [markdown]
# Выводы:
#
# Зависимость от площади квартиры.
# - По графику наблюдается практически прямая зависимость цены от площади.
# - Выше 170 кв.м появляются скачки.
# - С ростом площади растет цена квартир.
# - Диапазон изменения значений от 3 до 45 млн
# - Характер зависимости такой же как для общей выборки, но цены общая цена выше.
#
# Зависимость от удаленности от центра.
# - По графику наблюдается обратная зависимость цены от растояния от центра.
# - Самая высокая стоимость в пределах первых 1 км - 13,5млн., далее снижение до 7 млн.
# - Есть выбивающиеся значения в районе 3 и 7 км.
# - Характер зависимости такой же как для общей выборки.
#
# Зависимость от этажа размещения.
# - Самая высокая цена квартир для категории этажей другой - 9 млн.
# - Долее последний этаж - 8,8 млн.
# - Самые дешевые квартиры на первом этаже - 6,2 млн.
# - Характер зависимости такой же как для общей выборки.
#
# Зависимость от количества комнат.
# - Наблюдается прямая зависимость.
# - Цена растет от 4 млн для студий до 17 млн для 6-комнатных квартир.
# - Характер зависимости такой же как для общей выборки. Диапазон типичных значений оказался уже 1-4 комнаты.
#
# Зависимость от даты размещения:
# - От дня недели зависимоти на наблюдается.
# - От месяца размещения зависимоти не наблюдается. Наблюдаются спад в 12 месяце (январь)
# - От года размещения зависимость есть. В 2014 году были самые высокие цены - 12,5 млн. Далее резкий спад к 2017 до 8,2 млн. Плавный рост цен к 2019 году до 9 млн.
# - Характер зависимости такой же как для общей выборки.

# %% [markdown]
# Сведу в таблицу основные типовые параметры квартир.

# %%
columns = ['Параметр','Все населенные пункты', 'Центр СПб']
data = [['Общая площадь квартир', '15 - 115 м.кв.', '15 - 180 м.кв.'],
        ['Цена', '12 тыс. - 12 млн.', '2.3 млн. - 25 млн.'],
        ['Количество комнат', '0 - 6', '1 - 4'],
        ['Высота потолков', '2,2 - 3,2 м', '2,5 - 3,5 м'],
        ['Время продажи', '20 - 520 дней', '50 - 750 дней'],
        ['Среднее время продажи', '102 дня', '141 дней']]

data_type_param = pd.DataFrame(data=data, columns=columns)

# %% [markdown]
# ### Проверка по всему датасету

# %% [markdown]
# Проведу последнюю проверку результатов для количественных параметров. Посчитаю корреляционную матрицу для всего датасета. Выделю из нее столбец с ценой. Выведу на экран тепловую диаграмму для оценки влияния всех величин на цену квартир.

# %%
corr_matrix = round(df_filtered.corr(), 2)
sb.set(rc = {'figure.figsize':(8,10)})
sb.heatmap(abs(corr_matrix.loc[:,['last_price']]).sort_values(by='last_price'), annot=True)
plt.title('Тепловая диаграмма влияния всех параметров \n исходного датасета на общую цену')
plt.show()

# %% [markdown]
# Выводы:
# 1. Наибольшее влияние на цену кравриры оказывают общая площадь квартиры и цена за квадратный метр (коэффициент корреляции 0,71 и 0,62 соответственно)
# 2. Так же оказывают влияние жилая площадь, количество комнат,высота потолков, удаленность от центра (коэффициент корреляции 0,57-0,31)
# 3. Остальные количественные параметры либо не оказываю влияние, либо оказывают, но не сильное.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# По результатам исследовательского анализа данных были выведены следющие типовые параметры продаваемых квартир:

# %%
display(data_type_param)
# Out:
#                 Параметр Все населенные пункты           Центр СПб
# 0  Общая площадь квартир        15 - 115 м.кв.      15 - 180 м.кв.
# 1                   Цена     12 тыс. - 12 млн.  2.3 млн. - 25 млн.
# 2      Количество комнат                 0 - 6               1 - 4
# 3        Высота потолков           2,2 - 3,2 м         2,5 - 3,5 м
# 4          Время продажи         20 - 520 дней       50 - 750 дней
# 5  Среднее время продажи               102 дня            141 дней

# %% [markdown]
# В центре Санкт-петербурга:
# 1. Выше распределение цен, как следствие продажа длится дольше.
# 2. Уже диапазон по количеству комнат и выше потолки. Это объясняется тем, что в центре в основном квартиры из старого фонда, они строились по другим стандартам.
# 3. Шире выборка по общей площади.
# 4. В общем результат ожидаемый, разница параметров объяснима.
#
# Влияние параметров на цены квартир:
# 1. Чем больше площадь квартиры, тем выше цена.
# 2. Чем дальше расположена от центра города квартира, тем цена ниже.
# 3. Чем больше комнат в квартире, тем выше цена.
# 4. Самая высокая стоимость квартир на этаже в группе - дрегой, далее квартиры на последнем этаже, самые дещевые на первом.
# 5. Зависимости от даты создания объявления нет. Наблюдались высокий рост цен в 2014 и 2019 годах.

# %% [markdown]
# Топ 10 городов с самым большим количеством объявлений:

# %%
display(locality_name_pivot)
# Out:
#                    price_square_meter  count
# locality_name
# Санкт-Петербург              104166.0  14123
# посёлок Мурино                86231.0    481
# посёлок Шушары                76876.0    418
# Всеволожск                    65843.0    380
# Пушкин                        99993.5    336
# Колпино                       74468.0    315
# посёлок Парголово             91337.0    304
# Гатчина                       67796.0    289
# деревня Кудрово               91666.0    277
# Выборг                        58133.0    224

# %% [markdown]
# 1. Наименьшая цена квадратного метра в Выборге 56221.
#
# 2. Наибольшая цена квадратного метра в Санкт-Петербурге 102941
#
# 3. Получен ожидаемый результат: наибольшая цена в пределах города, далее в Лен.области тенденция к снижению.

# %% [markdown]
# Следует братить внимание на следующие нюансы:
# 1. Пропуски в колоки с временем продажи квартиры. Их много, природа их не ясна, это могло повлиять на результаты исследоования.
# 2. Резкие выбросы в данных с периолом в 15 дней.
